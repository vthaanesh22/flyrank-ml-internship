# %% [markdown]
# <a href="https://colab.research.google.com/github/vthaanesh22/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/vthaanesh22/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# I frame my Refresh / Content Opportunity Scoring lane as a scoring task. The goal is to give each content page a score that helps prioritize which pages should be reviewed first. A higher score would indicate that a page appears more worthy of review based on the available data. This supports the content team's decision about where to spend limited review time.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# The target I would ideally like to predict is whether a page genuinely needs a refresh and would benefit from one. That outcome is not directly observed in the starter data, so I will use the page's current downward trend as a proxy for now. This proxy comes from the defined trend_direction field, where a downward trend is treated as an initial signal. It is not proof that the page will decline in the future or that a refresh will improve it.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# I will use Precision@K as the main success metric, with K representing the number of pages the content team can realistically review. This metric tells me what fraction of the top-ranked pages match the chosen proxy target. It fits the decision because the goal is to put the most useful pages near the top of the review list, rather than to make every prediction equally accurate.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# The unit of analysis is one content page. Each row represents one page and contains its available search, content, and engagement signals. The model or scoring method would assign a score to each page so that pages can be compared and prioritized for review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

url = "https://raw.githubusercontent.com/vthaanesh22/flyrank-ml-internship/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

df[[
    "client_id",
    "content_id",
    "impressions_90d",
    "sessions_90d",
    "trend_direction"
]].head()
# Out:
#            client_id            content_id  impressions_90d  sessions_90d  \
# 0  client_f369cb89fc  content_304f48230142             3803            17
# 1  client_4e07408562  content_a1fb4e703a9e            15320             9
# 2  client_7f2253d7e2  content_9aa793d4d895            12581            11
# 3  client_19581e27de  content_331d6c4de07b            11751            78
# 4  client_3fdba35f04  content_d99b7a2d90ca            19140           145
#
#   trend_direction
# 0            down
# 1            down
# 2            down
# 3          stable
# 4            down

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A fixed rule could prioritize pages using one or two thresholds, but page performance can depend on several signals at the same time, such as impressions, sessions, engagement, content age, and trend. ML may be useful if it can learn combinations of these signals that produce a better review ranking than a simple rule. I will need to compare the ML approach with a transparent fixed-rule baseline rather than assume ML is better.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
